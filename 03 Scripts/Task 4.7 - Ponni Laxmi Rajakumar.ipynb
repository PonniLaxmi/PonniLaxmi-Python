# %% [markdown]
# # Task 4.7- Deriving New Variables

# %% [markdown]
# 1. Import Libraries
# 2. Import data
# 3. If statement with user-defined functions
# 4. If statement with loc() function
# 5. If statement with For-Loops
# 6. Answers to task 4.7
# 7. Export data

# %% [markdown]
# # 1. Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Import data

# %%
# Defining path
path=r'C:\Users\ponni\Achievement 4'

# %%
# Import merged data
df_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Create a subset of the data
df=df_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %% [markdown]
# # 3. If statement with user-defined functions

# %%
# Define a function for subset
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range product'
  else: return 'Not enough data'

# %%
# Apply the function
df['price_range']=df.apply(price_label, axis=1)
# Out:
# C:\Users\ponni\AppData\Local\Temp\ipykernel_9608\969816975.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range']=df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# # 4. If statement with loc() function

# %%
# defining with loc function for subset 
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\ponni\AppData\Local\Temp\ipykernel_9608\548070678.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
# defining with loc function for full dataframe
df_merged.loc[df_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_merged.loc[(df_merged['prices'] <= 15) & (df_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_merged.loc[df_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # 5. If statement with For-Loops

# %%
# The frequency of highest ordered days
df_merged['order_dow'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_dow, dtype: int64

# %%
# Creating a new column 'busiest day'
result = []

for value in df_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Adding the new column to ur dataframe
df_merged['busiest day'] = result

# %%
df_merged['busiest day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest day, dtype: int64

# %%
df_merged
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2398795        1             2          3                  7
# 2           473747        1             3          3                 12
# 3          2254736        1             4          4                  7
# 4           431534        1             5          4                 15
# ...            ...      ...           ...        ...                ...
# 32404854   1320836   202557            17          2                 15
# 32404855     31526   202557            18          5                 11
# 32404856    758936   203436             1          2                  7
# 32404857   2745165   203436             2          3                  5
# 32404858   3093936   205420             1          4                 14
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %% [markdown]
# # 6. Answers to task 4.7

# %% [markdown]
# Q2

# %%
labeling_counts = df_merged['order_dow'].value_counts(dropna = False)

# %%
labeling_counts
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_dow, dtype: int64

# %%
labeling_counts.index
# Out:
# Int64Index([0, 1, 6, 2, 5, 3, 4], dtype='int64')

# %%
# As index in this case is day number and sorted (ascending), 2 busiest days and 2 slowest days are found.
# I will use it as automated comparison for the days labeling by converting into list.

day_number = list(labeling_counts.index)

# %%
day_number
# Out:
# [0, 1, 6, 2, 5, 3, 4]

# %%
results = []

# %%
for value in df_merged['order_dow']:
    if value == day_number[0] or value == day_number[1]:
        results.append('Busiest days')
    elif value == day_number[len(day_number) - 1] or value == day_number[len(day_number) - 2]:
        results.append('Slowest days')
    else:
        results.append('Regulary busy days')

# %%
# Checking if results length = DataFrame length

len(results)
# Out:
# 32404859

# %%
df_merged['order_dow'].shape
# Out:
# (32404859,)

# %%
# Results length corresponds to the DataFrame. We can just merge it.
# Create a new column in 'df_merged' named busiest_days

df_merged['busiest_days'] = results

# %% [markdown]
# Q3) Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
df_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regulary busy days    12916111
# Busiest days          11864412
# Slowest days           7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# Q4) When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
# Reminding of how the data looks like

df_merged.head(5)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                   999.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# ...

# %%
# Converting frequency into dictionary
dict_labeling_counts = df_merged['order_hour_of_day'].value_counts(dropna = False).to_dict()

# %%
# Checking frequency dictionary
dict_labeling_counts
# Out:
# {10: 2761760,
#  11: 2736140,
#  14: 2689136,
#  15: 2662144,
#  13: 2660954,
#  12: 2618532,
#  16: 2535202,
#  9: 2454203,
#  17: 2087654,
#  8: 1718118,
#  18: 1636502,
#  19: 1258305,
#  20: 976156,
#  7: 891054,
#  21: 795637,
#  22: 634225,
#  23: 402316,
#  6: 290493,
#  0: 218769,
#  1: 115700,
#  5: 87961,
#  2: 69375,
#  4: 53242,
#  3: 51281}

# %%
# Grouping into Most orders, Average orders and Fewest orders, I decided to use percentile as criteria.

list_quantile = list(df_merged['order_hour_of_day'].value_counts(dropna = False).quantile([0.75, 0.5, 0.25]))

# %%
list_quantile
# Out:
# [2556034.5, 1117230.5, 272562.0]

# %%
results_labeling_hour = []

# %%
# I used percentiles and nested loop here for grouping automation, 
# instead of hardcoding it using value 'order_hour_of_day' in the If-Statement.

for value in df_merged['order_hour_of_day']:
    for key, val in dict_labeling_counts.items():
        if value == key:
            if val < list_quantile[2]:
                results_labeling_hour.append('Fewest orders')
            elif val >= list_quantile[2] and val < list_quantile[1]:
                results_labeling_hour.append('Average orders')
            elif val >= list_quantile[1]:
                results_labeling_hour.append('Most orders')

# %%
# Function to check the list before merging it with the DataFrame
def labeling_result (x):
    most_orders = x.count('Most orders')
    average_orders = x.count('Average orders')
    fewest_orders = x.count('Fewest orders')
    
    print(f'Most orders: {most_orders}')
    print(f'Average orders: {average_orders}')
    print(f'Fewest orders: {fewest_orders}')
    print(f'Total: {most_orders + average_orders + fewest_orders}')

# %%
# Checking the grouping process through nested loop.
labeling_result(results_labeling_hour)
# Out:
# Most orders: 27818650
# Average orders: 3989881
# Fewest orders: 596328
# Total: 32404859

# %%
df_merged['order_hour_of_day'].shape
# Out:
# (32404859,)

# %%
# Since both length corresponds to each other, we can integrate it into 'df_merged'.

# %%
df_merged['busiest_period_of_day'] = results_labeling_hour

# %% [markdown]
# Q5) Print the frequency for this new column.

# %%
df_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       27818650
# Average orders     3989881
# Fewest orders       596328
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# # 7. Export the data

# %%
# Export the data
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_update.pkl'))
